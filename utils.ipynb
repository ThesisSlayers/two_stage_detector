# %%
import xml.etree.ElementTree as ET
import cv2

# %%
from pathlib import Path
from matplotlib import pyplot as plt

# %%
img_path = Path('/mnt/data/smarttray/dataset_05jul2021_av3b/run_3_revisited_5may2021/val/images/1610714264070_11.jpg')
xml_path = img_path.parent.parent/'annotations'/(img_path.stem+'.xml')
img_path.exists(), xml_path.exists()
# Out:
# (True, True)

# %%
from utils import read_xml_content

bbs = read_xml_content(xml_path)
bbs = [[y1,x1,y2,x2] for _,x1,y1,x2,y2 in bbs] 
bbs
# Out:
# [[486, 629, 1262, 1379], [1571, 728, 2043, 1149], [1446, 1407, 1933, 2156]]

# %%
from utils import draw_bbs

img = cv2.imread(str(img_path))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
draw_bbs(img, bbs)
plt.imshow(img)
# Out:
# 486 629 1262 1379
# 1571 728 2043 1149
# 1446 1407 1933 2156
